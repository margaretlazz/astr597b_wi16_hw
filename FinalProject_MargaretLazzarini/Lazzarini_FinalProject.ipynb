# %% [markdown]
# # Final Homework
# ## Galex YAML file for AIS, DR6
# ### Margaret Lazzarini, ASTR 597
# Winter 2016

# %% [markdown]
# Problem Statement:
# In class, you gave a presentation on a large survey project. For this homework, write:
# An LSD YAML table schema (.yaml file), and,
# the lsd-import command line (or any additional code or scripts) for a catalog from the survey you discussed.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.table import Table, Column
import pandas as pd
import sqlite3

# %%
from lsd import DB
from lsd.bounds import beam, rectangle

# %%
import os
os.environ['NWORKERS'] = '8'
os.environ['LSD_CACHEDIR'] = os.environ['HOME'] + '/tempdir'
os.environ['LSD_TEMPDIR'] = os.environ['HOME'] + '/tempdir'
os.environ['LSD_DB'] = os.environ['HOME'] + '/lsddb:/astro/apps6/opt/lsddb'

# %%
#Double checking environmental parameters
print os.environ['NWORKERS']
print os.environ['LSD_DB']
print os.environ['LSD_CACHEDIR']
print os.environ['LSD_TEMPDIR']
# Out:
# 8
# /astro/users/mlazz/lsddb:/astro/apps6/opt/lsddb
# /astro/users/mlazz/tempdir
# /astro/users/mlazz/tempdir

# %%
# !ls
# Out:
# ~			     galex.yaml			   python_demo.ipynb
# AIS_26_sg95-xd-mcat.fits     homework1_sdssdownload.csv    questionnaire
# AIS_395_sg85-xd-mcat.fits    hw1_MargaretLazzarini.ipynb   README.md
# calibObj-000094-1-star.fits  hw1_sdss.yaml		   scripts
# calibObj-000094-2-star.fits  hw2_MargaretLazzarini.ipynb   starsdb
# calibObj-000094-3-star.fits  Lazzarini_FinalProject.ipynb  stars.db
# calibObj-000094-4-star.fits  lectures			   tile26.fits
# calibObj-000094-5-star.fits  LSD_handson_practice_2.ipynb  tile395.fits
# data			     LSD_handson_practice.ipynb    usnob.yaml
# foot.fits		     mysdss.db

# %%
#I downloaded one tile of GALEX data so I can preview the contained columns to write the YAML file
t = Table.read('/astro/users/mlazz/astr597b_wi16/AIS_395_sg85-xd-mcat.fits')
t[:5]
# Out:
# WARNING: UnitsWarning: 'string' did not parse as fits unit: At col 0, Unit 'string' not supported by the FITS standard.  [astropy.units.core]
# WARNING:astropy:UnitsWarning: 'string' did not parse as fits unit: At col 0, Unit 'string' not supported by the FITS standard.
# WARNING: UnitsWarning: 'number' did not parse as fits unit: At col 0, Unit 'number' not supported by the FITS standard.  [astropy.units.core]
# WARNING:astropy:UnitsWarning: 'number' did not parse as fits unit: At col 0, Unit 'number' not supported by the FITS standard.
# WARNING: UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.  [astropy.units.core]
# WARNING:astropy:UnitsWarning: 'degrees' did not parse as fits unit: At col 0, Unit 'degrees' not supported by the FITS standard.
# WARNING: UnitsWarning: 'probability' did not parse as fits unit: At col 0, Unit 'probability' not supported by the FITS standard.  [astropy.units.core]
# ...

# %%
t.info
# Out:
# <Table length=3402>
#           name           dtype  shape         unit
# ----------------------- ------- ----- --------------------
#               ggoid_hex   str16                     string
#               ggoid_dec   str20                     string
#                   ggoid   int32  (2,)               number
#                     vsn   int32                     number
#                 tilenum   int32                     number
#                    type   int32                     number
#                      ow   int32                     number
#                    prod   int32                     number
#                     img   int32                     number
#                     try   int32                     number
#                    band   int32                     number
#                      id   int32                     number
#                subvisit   int16                     number
#                     leg   int16                     number
# ...

# %% [markdown]
# GALEX YAML file copy-pasted below. This is the file I used called galex.yaml to create the table in the following commands.

# %% [raw]
# # Schema for GALEX GR6 Catalogue AIS
# filters: {complevel: 5, complib: blosc}
# schema:
#   basic_quantities:
#     primary_key: galex_id
#     spatial_keys: [alpha_j2000, delta_j2000]
#     columns:
#     - [galex_id, u8]
#     - [ggoid_hex, a17]
#     - [ggoid_dec, a20]
#     - [ggoid, 2i4]
#     - [vsn, i4]
#     - [tilenum, i4]
#     - [type, i4]
#     - [ow, i4]
#     - [prod, i4]
#     - [img, i4]
# #    - [try, i4]
#     - [band, i4]
#     - [id, i4]
#     - [subvisit, i2]
#     - [leg, i2]
#     - [alpha_j2000, f8]
#     - [delta_j2000, f8]
#     - [alpha_j2000_merged, f8]
#     - [delta_j2000_merged, f8]
#     - [prob, f4]
#     - [sep, f4]
#     - [sep_img, f4]
#     - [E_bv, f4]
#     - [glon, f4]
#     - [glat, f4]
#     - [primary, i4]
#     - [fov_radius, f4]
#   values_errors:
#     columns:
#     - [nuv_det_x, f4]
#     - [nuv_det_y, f4]
#     - [fuv_det_x, f4]
#     - [fuv_det_y, f4]
#     - [chkobj_type, i4]
#     - [chkobj_id, i4]
#     - [chkobj_r, f4]
#     - [chkobj_pa, f4]
#     - [misc_flags, i4]
#     - [nuv_flux, f4]
#     - [nuv_fluxerr, f4]
#     - [nuv_mag, f4]
#     - [nuv_magerr, f4]
#     - [fuv_flux, f4]
#     - [fuv_fluxerr, f4]
#     - [fuv_mag, f4]
#     - [fuv_magerr, f4]
#     - [nuv_s2n, f4]
#     - [fuv_s2n, f4]
#     - [nuv_fcat_flux, f4]
#     - [nuv_fcat_fluxerr, f4]
#     - [fuv_ncat_flux, f4]
#     - [fuv_ncat_fluxerr, f4]
#     - [fuv_ra_adj, f8]
#     - [fuv_dec_adj, f8]
#     - [fuv_ncat_flags, i2]
#     - [fuv_ncat_mag, f4]
#     - [fuv_ncat_magerr, f4]
#     - [fuv_ncat_s2n, f4]
#     - [nuv_fcat_mag, f4]
#     - [nuv_fcat_magerr, f4]
#     - [nuv_fcat_s2n, f4]
#     - [fuv_ncat_fwhm_image, f4]
#     - [fuv_ncat_fwhm_world, f4]
#     - [fuv_ncat_flux_radius_1, f4]
#     - [fuv_ncat_flux_radius_2, f4]
#     - [fuv_ncat_flux_radius_3, f4]
#     - [fuv_ncat_flux_radius_4, f4]
#     - [fuv_ncat_flux_radius_5, f4]
#     - [fuv_ncat_flux_aper_1, f4]
#     - [fuv_ncat_flux_aper_2, f4]
#     - [fuv_ncat_flux_aper_3, f4]
#     - [fuv_ncat_flux_aper_4, f4]
#     - [fuv_ncat_flux_aper_5, f4]
#     - [fuv_ncat_flux_aper_6, f4]
#     - [fuv_ncat_flux_aper_7, f4]
#     - [fuv_ncat_fluxerr_aper_1, f4]
#     - [fuv_ncat_fluxerr_aper_2, f4]
#     - [fuv_ncat_fluxerr_aper_3, f4]
#     - [fuv_ncat_fluxerr_aper_4, f4]
#     - [fuv_ncat_fluxerr_aper_5, f4]
#     - [fuv_ncat_fluxerr_aper_6, f4]
#     - [fuv_ncat_fluxerr_aper_7, f4]
#     - [fuv_ncat_mag_aper_1, f4]
#     - [fuv_ncat_mag_aper_2, f4]
#     - [fuv_ncat_mag_aper_3, f4]
#     - [fuv_ncat_mag_aper_4, f4]
#     - [fuv_ncat_mag_aper_5, f4]
#     - [fuv_ncat_mag_aper_6, f4]
#     - [fuv_ncat_mag_aper_7, f4]
#     - [fuv_ncat_magerr_aper_1, f4]
#     - [fuv_ncat_magerr_aper_2, f4]
#     - [fuv_ncat_magerr_aper_3, f4]
#     - [fuv_ncat_magerr_aper_4, f4]
#     - [fuv_ncat_magerr_aper_5, f4]
#     - [fuv_ncat_magerr_aper_6, f4]
#     - [fuv_ncat_magerr_aper_7, f4]
#     - [nuv_nc_r1, i2]
#     - [nuv_nc_r2, i2]
#     - [nuv_nc_r3, i2]
#     - [fuv_nc_r1, i2]
#     - [fuv_nc_r2, i2]
#     - [fuv_nc_r3, i2]
#     - [nuv_nf_r1, f4]
#     - [nuv_nf_r2, f4]
#     - [nuv_nf_r3, f4]
#     - [fuv_nf_r1, f4]
#     - [fuv_nf_r2, f4]
#     - [fuv_nf_r3, f4]
#     - [cn_radius, f4]
#     - [cn_pa, f4]
#     - [cn_mag_nuv, f4]
#     - [cn_mag_fuv, f4]
#     - [nuv_skybg, f4]
#     - [fuv_skybg, f4]
#     - [nuv_weight, f4]
#     - [fuv_weight, f4]
#     - [nuv_int, f4]
#     - [fuv_int, f4]
#     - [nuv_thres, f4]
#     - [fuv_thres, f4]
#     - [nuv_contrast, f4]
#     - [fuv_contrast, f4]
#     - [nuv_scq_mdn, f4]
#     - [nuv_scq_p05, f4]
#     - [nuv_scq_p95, f4]
#     - [fuv_scq_mdn, f4]
#     - [fuv_scq_p05, f4]
#     - [fuv_scq_p95, f4]
#     - [nuv_maskpix, i4]
#     - [fuv_maskpix, i4]
#     - [nuv_artifact, i4]
#     - [fuv_artifact, i4]
#     - [nuv_scx, f4]
#     - [nuv_scy, f4]
#     - [fuv_scx, f4]
#     - [fuv_scy, f4]
#     - [nuv_Q, f4]
#     - [fuv_Q, f4]
#     - [nuv_ambg, i4]
#     - [fuv_ambg, i4]
#     - [nuv_nc, i4]
#     - [fuv_nc, i4]
#     - [nuv_cid1, i4]
#     - [fuv_cid1, i4]
#     - [nuv_cid2, i4]
#     - [fuv_cid2, i4]
#     - [nuv_cid3, i4]
#     - [fuv_cid3, i4]
#     - [nuv_poserr, f4]
#     - [fuv_poserr, f4]
#     - [ib_poserr, f4]
#     - [nuv_pperr, f4]
#     - [fuv_pperr, f4]
#     - [match_reliability, f4]
#     - [sourcepa, f4]
#   NUV_calib:
#     columns:
#     - [NUV_NUMBER, i4]
#     - [NUV_FLUX_ISO, f4]
#     - [NUV_FLUXERR_ISO, f4]
#     - [NUV_MAG_ISO, f4]
#     - [NUV_MAGERR_ISO, f4]
#     - [NUV_FLUX_APER_1, f4]
#     - [NUV_FLUX_APER_2, f4]
#     - [NUV_FLUX_APER_3, f4]
#     - [NUV_FLUX_APER_4, f4]
#     - [NUV_FLUX_APER_5, f4]
#     - [NUV_FLUX_APER_6, f4]
#     - [NUV_FLUX_APER_7, f4]
#     - [NUV_FLUXERR_APER_1, f4]
#     - [NUV_FLUXERR_APER_2, f4]
#     - [NUV_FLUXERR_APER_3, f4]
#     - [NUV_FLUXERR_APER_4, f4]
#     - [NUV_FLUXERR_APER_5, f4]
#     - [NUV_FLUXERR_APER_6, f4]
#     - [NUV_FLUXERR_APER_7, f4]
#     - [NUV_MAG_APER_1, f4]
#     - [NUV_MAG_APER_2, f4]
#     - [NUV_MAG_APER_3, f4]
#     - [NUV_MAG_APER_4, f4]
#     - [NUV_MAG_APER_5, f4]
#     - [NUV_MAG_APER_6, f4]
#     - [NUV_MAG_APER_7, f4]
#     - [NUV_MAGERR_APER_1, f4]
#     - [NUV_MAGERR_APER_2, f4]
#     - [NUV_MAGERR_APER_3, f4]
#     - [NUV_MAGERR_APER_4, f4]
#     - [NUV_MAGERR_APER_5, f4]
#     - [NUV_MAGERR_APER_6, f4]
#     - [NUV_MAGERR_APER_7, f4]
#     - [NUV_FLUX_AUTO, f4]
#     - [NUV_FLUXERR_AUTO, f4]
#     - [NUV_MAG_AUTO, f4]
#     - [NUV_MAGERR_AUTO, f4]
#     - [NUV_FLUX_RADIUS_1, f4]
#     - [NUV_FLUX_RADIUS_2, f4]
#     - [NUV_FLUX_RADIUS_3, f4]
#     - [NUV_FLUX_RADIUS_4, f4]
#     - [NUV_FLUX_RADIUS_5, f4]
#     - [NUV_KRON_RADIUS, f4]
#     - [NUV_BACKGROUND, f4]
#     - [NUV_THRESHOLD, f4]
#     - [NUV_MU_THRESHOLD, f4]
#     - [NUV_FLUX_MAX, f4]
#     - [NUV_MU_MAX, f4]
#     - [NUV_ISOAREA_IMAGE, f4]
#     - [NUV_ISOAREA_WORLD, f4]
#     - [NUV_ISOAREAF_IMAGE, f4]
#     - [NUV_ISOAREAF_WORLD, f4]
#     - [NUV_XMIN_IMAGE, i4]
#     - [NUV_YMIN_IMAGE, i4]
#     - [NUV_XMAX_IMAGE, i4]
#     - [NUV_YMAX_IMAGE, i4]
#     - [NUV_X_IMAGE, f4]
#     - [NUV_Y_IMAGE, f4]
#     - [NUV_XPEAK_IMAGE, i4]
#     - [NUV_YPEAK_IMAGE, i4]
#     - [NUV_ALPHA_J2000, f8]
#     - [NUV_DELTA_J2000, f8]
#     - [NUV_X2_IMAGE, f4]
#     - [NUV_Y2_IMAGE, f4]
#     - [NUV_XY_IMAGE, f4]
#     - [NUV_X2_WORLD, f4]
#     - [NUV_Y2_WORLD, f4]
#     - [NUV_XY_WORLD, f4]
#     - [NUV_CXX_IMAGE, f4]
#     - [NUV_CYY_IMAGE, f4]
#     - [NUV_CXY_IMAGE, f4]
#     - [NUV_CXX_WORLD, f4]
#     - [NUV_CYY_WORLD, f4]
#     - [NUV_CXY_WORLD, f4]
#     - [NUV_A_IMAGE, f4]
#     - [NUV_B_IMAGE, f4]
#     - [NUV_A_WORLD, f4]
#     - [NUV_B_WORLD, f4]
#     - [NUV_THETA_IMAGE, f4]
#     - [NUV_THETA_WORLD, f4]
#     - [NUV_THETA_J2000, f4]
#     - [NUV_ELONGATION, f4]
#     - [NUV_ELLIPTICITY, f4]
#     - [NUV_ERRX2_IMAGE, f8]
#     - [NUV_ERRY2_IMAGE, f8]
#     - [NUV_ERRXY_IMAGE, f4]
#     - [NUV_ERRX2_WORLD, f8]
#     - [NUV_ERRY2_WORLD, f8]
#     - [NUV_ERRXY_WORLD, f4]
#     - [NUV_ERRCXX_IMAGE, f4]
#     - [NUV_ERRCYY_IMAGE, f4]
#     - [NUV_ERRCXY_IMAGE, f4]
#     - [NUV_ERRCXX_WORLD, f4]
#     - [NUV_ERRCYY_WORLD, f4]
#     - [NUV_ERRCXY_WORLD, f4]
#     - [NUV_ERRA_IMAGE, f4]
#     - [NUV_ERRB_IMAGE, f4]
#     - [NUV_ERRA_WORLD, f4]
#     - [NUV_ERRB_WORLD, f4]
#     - [NUV_ERRTHETA_IMAGE, f4]
#     - [NUV_ERRTHETA_WORLD, f4]
#     - [NUV_ERRTHETA_J2000, f4]
#     - [NUV_FWHM_IMAGE, f4]
#     - [NUV_FWHM_WORLD, f4]
#     - [NUV_FLAGS, i2]
#     - [NUV_CLASS_STAR, f4]
#   FUV_calib:
#     columns:
#     - [FUV_NUMBER, i4]
#     - [FUV_FLUX_ISO, f4]
#     - [FUV_FLUXERR_ISO, f4]
#     - [FUV_MAG_ISO, f4]
#     - [FUV_MAGERR_ISO, f4]
#     - [FUV_FLUX_APER_1, f4]
#     - [FUV_FLUX_APER_2, f4]
#     - [FUV_FLUX_APER_3, f4]
#     - [FUV_FLUX_APER_4, f4]
#     - [FUV_FLUX_APER_5, f4]
#     - [FUV_FLUX_APER_6, f4]
#     - [FUV_FLUX_APER_7, f4]
#     - [FUV_FLUXERR_APER_1, f4]
#     - [FUV_FLUXERR_APER_2, f4]
#     - [FUV_FLUXERR_APER_3, f4]
#     - [FUV_FLUXERR_APER_4, f4]
#     - [FUV_FLUXERR_APER_5, f4]
#     - [FUV_FLUXERR_APER_6, f4]
#     - [FUV_FLUXERR_APER_7, f4]
#     - [FUV_MAG_APER_1, f4]
#     - [FUV_MAG_APER_2, f4]
#     - [FUV_MAG_APER_3, f4]
#     - [FUV_MAG_APER_4, f4]
#     - [FUV_MAG_APER_5, f4]
#     - [FUV_MAG_APER_6, f4]
#     - [FUV_MAG_APER_7, f4]
#     - [FUV_MAGERR_APER_1, f4]
#     - [FUV_MAGERR_APER_2, f4]
#     - [FUV_MAGERR_APER_3, f4]
#     - [FUV_MAGERR_APER_4, f4]
#     - [FUV_MAGERR_APER_5, f4]
#     - [FUV_MAGERR_APER_6, f4]
#     - [FUV_MAGERR_APER_7, f4]
#     - [FUV_FLUX_AUTO, f4]
#     - [FUV_FLUXERR_AUTO, f4]
#     - [FUV_MAG_AUTO, f4]
#     - [FUV_MAGERR_AUTO, f4]
#     - [FUV_FLUX_RADIUS_1, f4]
#     - [FUV_FLUX_RADIUS_2, f4]
#     - [FUV_FLUX_RADIUS_3, f4]
#     - [FUV_FLUX_RADIUS_4, f4]
#     - [FUV_FLUX_RADIUS_5, f4]
#     - [FUV_KRON_RADIUS, f4]
#     - [FUV_BACKGROUND, f4]
#     - [FUV_THRESHOLD, f4]
#     - [FUV_MU_THRESHOLD, f4]
#     - [FUV_FLUX_MAX, f4]
#     - [FUV_MU_MAX, f4]
#     - [FUV_ISOAREA_IMAGE, f4]
#     - [FUV_ISOAREA_WORLD, f4]
#     - [FUV_ISOAREAF_IMAGE, f4]
#     - [FUV_ISOAREAF_WORLD, f4]
#     - [FUV_XMIN_IMAGE, i4]
#     - [FUV_YMIN_IMAGE, i4]
#     - [FUV_XMAX_IMAGE, i4]
#     - [FUV_YMAX_IMAGE, i4]
#     - [FUV_X_IMAGE, f4]
#     - [FUV_Y_IMAGE, f4]
#     - [FUV_XPEAK_IMAGE, i4]
#     - [FUV_YPEAK_IMAGE, i4]
#     - [FUV_ALPHA_J2000, f8]
#     - [FUV_DELTA_J2000, f8]
#     - [FUV_X2_IMAGE, f4]
#     - [FUV_Y2_IMAGE, f4]
#     - [FUV_XY_IMAGE, f4]
#     - [FUV_X2_WORLD, f4]
#     - [FUV_Y2_WORLD, f4]
#     - [FUV_XY_WORLD, f4]
#     - [FUV_CXX_IMAGE, f4]
#     - [FUV_CYY_IMAGE, f4]
#     - [FUV_CXY_IMAGE, f4]
#     - [FUV_CXX_WORLD, f4]
#     - [FUV_CYY_WORLD, f4]
#     - [FUV_CXY_WORLD, f4]
#     - [FUV_A_IMAGE, f4]
#     - [FUV_B_IMAGE, f4]
#     - [FUV_A_WORLD, f4]
#     - [FUV_B_WORLD, f4]
#     - [FUV_THETA_IMAGE, f4]
#     - [FUV_THETA_WORLD, f4]
#     - [FUV_THETA_J2000, f4]
#     - [FUV_ELONGATION, f4]
#     - [FUV_ELLIPTICITY, f4]
#     - [FUV_ERRX2_IMAGE, f8]
#     - [FUV_ERRY2_IMAGE, f8]
#     - [FUV_ERRXY_IMAGE, f4]
#     - [FUV_ERRX2_WORLD, f8]
#     - [FUV_ERRY2_WORLD, f8]
#     - [FUV_ERRXY_WORLD, f4]
#     - [FUV_ERRCXX_IMAGE, f4]
#     - [FUV_ERRCYY_IMAGE, f4]
#     - [FUV_ERRCXY_IMAGE, f4]
#     - [FUV_ERRCXX_WORLD, f4]
#     - [FUV_ERRCYY_WORLD, f4]
#     - [FUV_ERRCXY_WORLD, f4]
#     - [FUV_ERRA_IMAGE, f4]
#     - [FUV_ERRB_IMAGE, f4]
#     - [FUV_ERRA_WORLD, f4]
#     - [FUV_ERRB_WORLD, f4]
#     - [FUV_ERRTHETA_IMAGE, f4]
#     - [FUV_ERRTHETA_WORLD, f4]
#     - [FUV_ERRTHETA_J2000, f4]
#     - [FUV_FWHM_IMAGE, f4]
#     - [FUV_FWHM_WORLD, f4]
#     - [FUV_FLAGS, i2]
#     - [FUV_CLASS_STAR, f4]

# %%
! lsd-admin create table --schema galex.yaml galex_tile395 --drop-existing
# Out:
# Table 'galex_tile395' dropped.
#
# -------- committing 20160310002254.316174 [galex_tile395] ---------
# [galex_tile395] Updating tablet catalog: [256 el.]::::::::::::::::::::>  0.19 sec
# [galex_tile395] Updating neighbors: Already up to date.
# [galex_tile395] Updating tablet catalog: [256 el.]::::::::::::::::::::>  0.21 sec
# [galex_tile395] Updating stats: [0 el.]>  0.00 sec
# [galex_tile395] Marking tablets read-only...
# ----------- success 20160310002254.316174 [galex_tile395] ---------
#
# Table 'galex_tile395' created.

# %%
! lsd-import fits galex_tile395 'AIS_395_sg85-xd-mcat.fits'
# Out:
# Importing from 1 pieces:
#   ===> Imported AIS_395_sg85-xd-mcat.fits                                              [1/1, 100.00%] +   6272/6272         6272 (0/0 min.)
# done
#
# -------- committing 20160310002303.740642 [galex_tile395] ---------
# [galex_tile395] Updating tablet catalog: [256 el.]::::::::::::::::::::>  0.25 sec
# [galex_tile395] Updating neighbors: [2 el.]::::::::::::::::::::[12 el.]++++++++++++++++++++>  2.81 sec
#                 Total 1000 cached objects in 12 cells
# [galex_tile395] Updating tablet catalog: [256 el.]::::::::::::::::::::>  0.35 sec
# [galex_tile395] Updating stats: [12 el.]::::::::::::::::::::>  0.03 sec [12 el.]::::::::::::::::::::>  0.13 sec
# [galex_tile395] Marking tablets read-only...
# ----------- success 20160310002303.740642 [galex_tile395] ---------

# %%
! lsd-footprint galex_tile395 tile395.fits
# Out:
#  [2 el.]::::::::::::::::::::>  0.19 sec
# Objects: 6272.0
